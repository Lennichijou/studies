# %%
import pandas as pd
data = pd.read_csv('Churn_Modelling.csv')

# %%
try:
    import scikeras
except ImportError:
    # !python -m pip install scikeras
# Out:
# Collecting scikeras
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (3.4.1)
# Collecting scikit-learn>=1.4.2 (from scikeras)
#   Downloading scikit_learn-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (24.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Downloading scikit_learn-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 49.3 MB/s eta 0:00:00
# Installing collected packages: scikit-learn, scikeras
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.2
#     Uninstalling scikit-learn-1.3.2:
#       Successfully uninstalled scikit-learn-1.3.2
# Successfully installed scikeras-0.13.0 scikit-learn-1.5.1

# %%
import numpy as np
import matplotlib.pyplot as plt
import copy

from sklearn import ensemble
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

from tensorflow.keras.utils import to_categorical
from keras import models
from keras import layers

import warnings
warnings.filterwarnings("ignore")

# %%
data.sample(10)
# Out:
#       RowNumber  CustomerId         Surname  CreditScore Geography  Gender  \
# 5315       5316    15572956           Steen          683    France    Male
# 6458       6459    15783526        Le Hunte          589    France    Male
# 4533       4534    15607275          Ch'ang          850     Spain    Male
# 7467       7468    15803682          Angelo          651   Germany  Female
# 6212       6213    15638231           Chung          730     Spain  Female
# 3367       3368    15648881            Tsai          581   Germany    Male
# 2574       2575    15688691             Lei          665   Germany  Female
# 1979       1980    15635597  Echezonachukwu          644    France    Male
# 817         818    15806438       Chiabuotu          580   Germany  Female
# 6467       6468    15641782       Humphries          540    France  Female
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 5315   36       5  115350.63              1          1               1
# 6458   36       1  100895.54              1          1               1
# 4533   39       6  206014.94              2          0               1
# 7467   37      10  117791.06              2          1               1
# 6212   62       2       0.00              2          1               1
# 3367   40       0  101016.53              1          0               1
# 2574   51       9  110610.41              2          0               1
# 1979   33       8       0.00              2          1               1
# 817    42       2  123331.36              1          0               0
# 6467   31       7       0.00              1          0               1
#
#       EstimatedSalary  Exited
# 5315        122305.91       0
# 6458         68075.14       0
# 4533         42774.84       1
# 7467         75837.58       0
# 6212        162889.10       0
# 3367          7926.35       1
# 2574          1112.76       1
# 1979        155294.17       0
# 817         103516.08       1
# 6467        183051.60       1

# %%
dataset = data.copy()

del dataset['RowNumber']

del dataset['Gender']
del dataset['Surname']
del dataset['Geography']

# %%
del dataset['CustomerId']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
points = dataset['Exited']
values = dataset.drop(['Exited'], axis = 1)

train_points, test_points, train_values, test_values = train_test_split(values, points, test_size = 0.2)

# %%
model = models.Sequential()

model.add(layers.Dense(9, activation = "relu"))

model.add(layers.Dense(15, activation = "relu"))

model.add(layers.Dense(1, activation = "sigmoid"))

model.compile(
 optimizer = "adam",
 loss = "binary_crossentropy",
 metrics = ["accuracy"]
)
results = model.fit(
 train_points, train_values,
 epochs= 5,
 batch_size = 1000,
 validation_data = (test_points, test_values)
)
print("Test-Accuracy:", np.max(results.history["accuracy"]))
# Out:
# Epoch 1/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 0.2073 - loss: 8374.3008 - val_accuracy: 0.1950 - val_loss: 6532.1060
# Epoch 2/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.3308 - loss: 6070.4917 - val_accuracy: 0.4735 - val_loss: 4929.8882
# Epoch 3/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4623 - loss: 4654.2393 - val_accuracy: 0.4765 - val_loss: 3634.7041
# Epoch 4/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4677 - loss: 3420.1763 - val_accuracy: 0.4910 - val_loss: 2457.9365
# Epoch 5/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.4817 - loss: 2292.0796 - val_accuracy: 0.5240 - val_loss: 1484.0208
# Test-Accuracy: 0.49149999022483826

# %%
model = models.Sequential()

model.add(layers.Dense(9, activation = "relu"))

model.add(layers.Dense(15, activation = "relu"))

model.add(layers.Dense(1, activation = "sigmoid"))

model.compile(
 optimizer = "adam",
 loss = "binary_crossentropy",
 metrics = ["accuracy"]
)
results = model.fit(
 train_points, train_values,
 epochs= 5,
 batch_size = 100,
 validation_data = (test_points, test_values)
)
print("Test-Accuracy:", np.max(results.history["accuracy"]))
# Out:
# Epoch 1/5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.4730 - loss: 3790.1426 - val_accuracy: 0.7245 - val_loss: 542.4341
# Epoch 2/5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7191 - loss: 363.3714 - val_accuracy: 0.7190 - val_loss: 32.2764
# Epoch 3/5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6780 - loss: 29.9517 - val_accuracy: 0.6610 - val_loss: 12.9619
# Epoch 4/5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6933 - loss: 12.9926 - val_accuracy: 0.5350 - val_loss: 13.9473
# Epoch 5/5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6893 - loss: 14.7415 - val_accuracy: 0.7765 - val_loss: 11.8772
# Test-Accuracy: 0.7067499756813049

# %%
model = models.Sequential()

model.add(layers.Dense(9, activation = "relu"))

model.add(layers.Dense(15, activation = "relu"))

model.add(layers.Dense(1, activation = "sigmoid"))

model.compile(
 optimizer = "adam",
 loss = "binary_crossentropy",
 metrics = ["accuracy"]
)
results = model.fit(
 train_points, train_values,
 epochs= 10,
 batch_size = 100,
 validation_data = (test_points, test_values)
)
print("Test-Accuracy:", np.max(results.history["accuracy"]))
# Out:
# Epoch 1/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.7837 - loss: 4617.4453 - val_accuracy: 0.6495 - val_loss: 341.6584
# Epoch 2/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6754 - loss: 161.5824 - val_accuracy: 0.7125 - val_loss: 21.3354
# Epoch 3/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6480 - loss: 19.9837 - val_accuracy: 0.7255 - val_loss: 13.8188
# Epoch 4/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6618 - loss: 15.0222 - val_accuracy: 0.2600 - val_loss: 18.0475
# Epoch 5/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6495 - loss: 20.3170 - val_accuracy: 0.8015 - val_loss: 25.0558
# Epoch 6/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6940 - loss: 25.3586 - val_accuracy: 0.7080 - val_loss: 11.7906
# Epoch 7/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6643 - loss: 17.4288 - val_accuracy: 0.5180 - val_loss: 30.0086
# Epoch 8/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6708 - loss: 15.1482 - val_accuracy: 0.5475 - val_loss: 10.2053
# Epoch 9/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6715 - loss: 14.2439 - val_accuracy: 0.7860 - val_loss: 9.7509
# Epoch 10/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6731 - loss: 10.3281 - val_accuracy: 0.4745 - val_loss: 32.4066
# Test-Accuracy: 0.7534999847412109

# %%
model = models.Sequential()

model.add(layers.Dense(10, activation = "relu"))

model.add(layers.Dense(15, activation = "relu"))

model.add(layers.Dense(8, activation = "relu"))

model.add(layers.Dense(1, activation = "sigmoid"))

model.compile(
 optimizer = "adam",
 loss = "binary_crossentropy",
 metrics = ["accuracy"]
)
results = model.fit(
 train_points, train_values,
 epochs= 10,
 batch_size = 100,
 validation_data = (test_points, test_values)
)
print("Test-Accuracy:", np.max(results.history["accuracy"]))
# Out:
# Epoch 1/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7847 - loss: 11.6177 - val_accuracy: 0.8080 - val_loss: 0.6687
# Epoch 2/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7948 - loss: 0.6652 - val_accuracy: 0.8080 - val_loss: 0.6474
# Epoch 3/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7996 - loss: 0.6438 - val_accuracy: 0.8080 - val_loss: 0.6284
# Epoch 4/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7943 - loss: 0.6276 - val_accuracy: 0.8080 - val_loss: 0.6113
# Epoch 5/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7837 - loss: 0.6148 - val_accuracy: 0.8080 - val_loss: 0.5961
# Epoch 6/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7909 - loss: 0.5995 - val_accuracy: 0.8080 - val_loss: 0.5826
# Epoch 7/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7902 - loss: 0.5874 - val_accuracy: 0.8080 - val_loss: 0.5705
# Epoch 8/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7922 - loss: 0.5757 - val_accuracy: 0.8080 - val_loss: 0.5599
# Epoch 9/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7899 - loss: 0.5678 - val_accuracy: 0.8080 - val_loss: 0.5505
# Epoch 10/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7935 - loss: 0.5573 - val_accuracy: 0.8080 - val_loss: 0.5424
# Test-Accuracy: 0.7933750152587891

# %%
model = models.Sequential()

model.add(layers.Dense(15, activation = "relu"))

model.add(layers.Dense(10, activation = "relu"))

model.add(layers.Dense(10, activation = "relu"))

model.add(layers.Dense(1, activation = "sigmoid"))

model.compile(
 optimizer = "adam",
 loss = "binary_crossentropy",
 metrics = ["accuracy"]
)
results = model.fit(
 train_points, train_values,
 epochs= 10,
 batch_size = 100,
 validation_data = (test_points, test_values)
)
print("Test-Accuracy:", np.max(results.history["accuracy"]))
# Out:
# Epoch 1/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4649 - loss: 1851.4066 - val_accuracy: 0.7815 - val_loss: 8.5857
# Epoch 2/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7367 - loss: 5.8267 - val_accuracy: 0.8045 - val_loss: 2.2801
# Epoch 3/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7111 - loss: 1.9124 - val_accuracy: 0.8080 - val_loss: 2.2213
# Epoch 4/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7270 - loss: 1.6262 - val_accuracy: 0.8070 - val_loss: 1.0262
# Epoch 5/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6996 - loss: 1.7880 - val_accuracy: 0.8075 - val_loss: 5.4422
# Epoch 6/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7230 - loss: 3.6838 - val_accuracy: 0.8075 - val_loss: 3.7926
# Epoch 7/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7117 - loss: 1.8357 - val_accuracy: 0.8080 - val_loss: 2.2228
# Epoch 8/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7335 - loss: 1.4721 - val_accuracy: 0.3305 - val_loss: 6.0602
# Epoch 9/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6738 - loss: 3.6342 - val_accuracy: 0.8080 - val_loss: 0.7266
# Epoch 10/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7165 - loss: 2.3476 - val_accuracy: 0.8075 - val_loss: 1.4506
# Test-Accuracy: 0.7302500009536743

# %%
model = models.Sequential()

model.add(layers.Dense(15, activation = "relu"))

model.add(layers.Dense(10, activation = "relu"))

model.add(layers.Dense(10, activation = "relu"))

model.add(layers.Dense(1, activation = "sigmoid"))

model.compile(
 optimizer = "adam",
 loss = "binary_crossentropy",
 metrics = ["accuracy"]
)
results = model.fit(
 train_points, train_values,
 epochs= 25,
 batch_size = 100,
 validation_data = (test_points, test_values)
)
print("Test-Accuracy:", np.max(results.history["accuracy"]))
# Out:
# Epoch 1/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6785 - loss: 380.7517 - val_accuracy: 0.3520 - val_loss: 4.3926
# Epoch 2/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6471 - loss: 1.9528 - val_accuracy: 0.8080 - val_loss: 0.6488
# Epoch 3/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7479 - loss: 0.9343 - val_accuracy: 0.8080 - val_loss: 0.7526
# Epoch 4/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7556 - loss: 0.9650 - val_accuracy: 0.6985 - val_loss: 0.6661
# Epoch 5/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7667 - loss: 0.8873 - val_accuracy: 0.8080 - val_loss: 0.7491
# Epoch 6/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7622 - loss: 0.7885 - val_accuracy: 0.8080 - val_loss: 1.7925
# Epoch 7/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7598 - loss: 1.4441 - val_accuracy: 0.8080 - val_loss: 0.8616
# Epoch 8/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7729 - loss: 0.7549 - val_accuracy: 0.8080 - val_loss: 1.0878
# Epoch 9/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7819 - loss: 0.8820 - val_accuracy: 0.6865 - val_loss: 0.9601
# Epoch 10/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7653 - loss: 0.8180 - val_accuracy: 0.8080 - val_loss: 0.5952
# Epoch 11/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7712 - loss: 0.8590 - val_accuracy: 0.8080 - val_loss: 1.1921
# Epoch 12/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7719 - loss: 0.8358 - val_accuracy: 0.8080 - val_loss: 0.8402
# Epoch 13/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7732 - loss: 0.8112 - val_accuracy: 0.8080 - val_loss: 0.6928
# Epoch 14/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7729 - loss: 0.6955 - val_accuracy: 0.8080 - val_loss: 0.7294
# Epoch 15/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7538 - loss: 0.9807 - val_accuracy: 0.7225 - val_loss: 0.6584
# Epoch 16/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7754 - loss: 0.6487 - val_accuracy: 0.8080 - val_loss: 0.6481
# Epoch 17/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7573 - loss: 0.7464 - val_accuracy: 0.8070 - val_loss: 0.6898
# Epoch 18/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7662 - loss: 0.7097 - val_accuracy: 0.7475 - val_loss: 0.5598
# Epoch 19/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7681 - loss: 0.7379 - val_accuracy: 0.7010 - val_loss: 1.5652
# Epoch 20/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7635 - loss: 1.3336 - val_accuracy: 0.8075 - val_loss: 0.5406
# Epoch 21/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7775 - loss: 0.5737 - val_accuracy: 0.8075 - val_loss: 0.5197
# Epoch 22/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7761 - loss: 0.5890 - val_accuracy: 0.8080 - val_loss: 0.5033
# Epoch 23/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7830 - loss: 0.5706 - val_accuracy: 0.8080 - val_loss: 0.6452
# Epoch 24/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7870 - loss: 0.5713 - val_accuracy: 0.7325 - val_loss: 0.7221
# Epoch 25/25
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7665 - loss: 0.6406 - val_accuracy: 0.8080 - val_loss: 0.5642
# Test-Accuracy: 0.7836250066757202
